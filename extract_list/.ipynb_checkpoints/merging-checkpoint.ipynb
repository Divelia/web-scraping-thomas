# %%
# importing packages
import os
import re
import pandas as pd
import numpy as np
from IPython import display
from ipywidgets import interact, widgets
import matplotlib.pyplot as plt

# importing data
url_origin = 'outputs'
files = os.listdir(url_origin)
print('Total of files founded: ', len(files))
filenames = [re.findall(".*.xlsx", el)[0] for el in files]
# print('Files names: ', filenames)
# Out:
# Total of files founded:  35

# %%
# Standard names
bra = ['magalu', 'mundoverde', 'drogariasaopaulo', 'drogaraia', 'lojadosuplemento', 'submarino', 'mercadolibrebr', 'amazonbr', 'americanas', 'natue', 'magazine']
mex = ['mercadolibremx', 'amazonmx', 'walmart', 'sams', 'supernaturista', 'costco', 'sanborns', 'benavides', 'fahorro', 'sanpablofarmacia']

# %%
list_dataframes = []
total_rows = 0
for filename in filenames:
    try:
        df = pd.read_excel(url_origin + "//" + filename)
        headers = list(df.columns)
        webpage = re.search(r'.*\-', filename).group(0)[:-1].replace(' ', '')
        search = re.search(r'\-.*', filename).group(0)[1:-5]
        try:
            df['id'] = df.name.str[-2:] + df.image.str[-20:-10]
        except:
            df['id'] = df.image.str[-20:-10]
    
        df['site'] = webpage
        df['search'] = search
        print(webpage, ' has ', df.shape[0], ' datos')
        if webpage in bra:
            df['country'] = 'BRASIL (BRA)'
        elif webpage in mex:
            df['country'] = 'MEXICO (MEX)'
        else:
            df['country'] = 'No encontrado'
        print('columns: ', list(df.columns))
        current_cols = list(df.columns)
        cols_base = ['search', 'site', 'id', 'name', 'brand', 'price', 'oldprice', 'quantity', 'image', 'country']
        notpresent_cols = list(set(cols_base) - set(current_cols))
        for n in notpresent_cols:
            df[n] = np.nan
        df = df[cols_base]
        list_dataframes.append(df)
        print('\n')
        total_rows += df.shape[0]
    except Exception as e:
        print(e)
        continue
print('TOTAL OF ROWS: ', total_rows)
# Out:
# amazonbr  has  6336  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'id', 'site', 'search', 'country']
#
#
# amazonbr  has  1874  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'id', 'site', 'search', 'country']
#
#
# amazonmx  has  70  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'id', 'site', 'search', 'country']
#
#
# amazonmx  has  125  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'id', 'site', 'search', 'country']
#
#
# americanas  has  9984  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'promo', 'stock', 'id', 'site', 'search', 'country']
#
#
# americanas  has  9984  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'promo', 'stock', 'id', 'site', 'search', 'country']
#
#
# benavides  has  11  datos
# columns:  ['id', 'name', 'quantity', 'image', 'price', 'site', 'search', 'country']
#
#
# benavides  has  50  datos
# columns:  ['name', 'price', 'image', 'id', 'site', 'search', 'country']
#
#
# costco  has  157  datos
# columns:  ['name', 'price', 'image', 'oldprice', 'id', 'site', 'search', 'country']
#
#
# costco  has  453  datos
# columns:  ['name', 'price', 'image', 'oldprice', 'id', 'site', 'search', 'country']
#
#
# drogaraia  has  96  datos
# columns:  ['name', 'price', 'unique_price', 'lmpm_price', 'oldprice', 'image', 'quantity', 'id', 'site', 'search', 'country']
#
#
# drogaraia  has  120  datos
# columns:  ['name', 'price', 'unique_price', 'lmpm_price', 'oldprice', 'image', 'quantity', 'id', 'site', 'search', 'country']
#
#
# drogariasaopaulo  has  480  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'id', 'site', 'search', 'country']
#
#
# drogariasaopaulo  has  1680  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'id', 'site', 'search', 'country']
#
#
# lojadosuplemento  has  31  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'unique_price', 'lmpm_price', 'id', 'site', 'search', 'country']
#
#
# lojadosuplemento  has  15  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'unique_price', 'lmpm_price', 'id', 'site', 'search', 'country']
#
#
# magalu  has  243  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'kit', 'id', 'site', 'search', 'country']
#
#
# magalu  has  299  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'kit', 'id', 'site', 'search', 'country']
#
#
# magazine  has  60  datos
# columns:  ['name', 'price', 'image', 'id', 'site', 'search', 'country']
#
#
# mercadolibrebr  has  2450  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'id', 'site', 'search', 'country']
#
#
# mercadolibrebr  has  280  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'id', 'site', 'search', 'country']
#
#
# mercadolibremx  has  2214  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'id', 'site', 'search', 'country']
#
#
# mercadolibremx  has  2136  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'id', 'site', 'search', 'country']
#
#
# mundoverde  has  57  datos
# columns:  ['id', 'name', 'price', 'oldprice', 'category', 'image', 'site', 'search', 'country']
#
#
# natue  has  584  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'promo', 'id', 'site', 'search', 'country']
#
#
# natue  has  57  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'promo', 'id', 'site', 'search', 'country']
#
#
# sams  has  23  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'id', 'site', 'search', 'country']
#
#
# sams  has  30  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'id', 'site', 'search', 'country']
#
#
# sanborns  has  286  datos
# columns:  ['name', 'price', 'image', 'oldprice', 'id', 'site', 'search', 'country']
#
#
# sanpablofarmacia  has  354  datos
# columns:  ['name', 'price', 'image', 'quantity', 'id', 'site', 'search', 'country']
#
#
# submarino  has  3331  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'promo', 'stock', 'id', 'site', 'search', 'country']
#
#
# supernaturista  has  29  datos
# columns:  ['name', 'price', 'brand', 'oldprice', 'image', 'id', 'site', 'search', 'country']
#
#
# supernaturista  has  604  datos
# columns:  ['name', 'price', 'brand', 'oldprice', 'image', 'id', 'site', 'search', 'country']
#
#
# walmart  has  1008  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'brand', 'promo', 'id', 'site', 'search', 'country']
#
#
# walmart  has  672  datos
# columns:  ['name', 'price', 'oldprice', 'image', 'brand', 'promo', 'id', 'site', 'search', 'country']
#
#
# TOTAL OF ROWS:  46183

# %%
# join all tables
summary = pd.concat(list_dataframes, ignore_index=True)

# deleting rows with nan values
summary = summary.dropna(how='all', axis=0)

summary.head(10)
# Out:
#         search      site            id  \
# 0  suplementos  amazonbr  caPWkuL._AC_
# 1  suplementos  amazonbr  bsTydWL._AC_
# 2  suplementos  amazonbr  onQvg8L._AC_
# 3  suplementos  amazonbr  orplFLL._AC_
# 4  suplementos  amazonbr  0GJHvAL._AC_
# 5  suplementos  amazonbr  0gP0+cL._AC_
# 6  suplementos  amazonbr  um2jcaL._AC_
# 7  suplementos  amazonbr  0ghaafL._AC_
# 8  suplementos  amazonbr  0GPpi5L._AC_
# 9  suplementos  amazonbr  a)SLh+S._AC_
#
#                                                 name brand  price   oldprice  \
# 0     Nutriwhey Chocolate Pouch 907G, Integralmedica   NaN  50.63        NaN
# 1  Pré Hormonal Testodrol Gh - 60 Tabs Original -...   NaN   99.0        NaN
# 2  Best Whey (907G) - Sabor Brigadeiro Gourmet, A...   NaN  149.9        NaN
# 3                        Coq-10-60 Cápsulas, Vitafor   NaN  108.5        NaN
# 4                Creatina 300G, Integralmedica, 300G   NaN  52.99        NaN
# 5  Suplemento Fortifit Pro Baunilha Danone Nutric...   NaN  116.0        NaN
# 6  Top Whey 3W (900G) - Sabor Mais Performance - ...   NaN   97.8  R$ 104,99
# 7  Nutren Protein, Suplemento Alimentar, Chocolat...   NaN  49.99   R$ 56,23
# 8       Creatine Pure Monohydrate, Black Skull, 150G   NaN   25.0        NaN
# 9  100% Whey Protein Refil 900g - Max Titanium (b...   NaN  70.31   R$ 93,00
#
#   quantity                                              image       country
# 0      NaN  https://m.media-amazon.com/images/I/817zMBPWku...  BRASIL (BRA)
# 1      NaN  https://m.media-amazon.com/images/I/71KNWOTydW...  BRASIL (BRA)
# 2      NaN  https://m.media-amazon.com/images/I/912c8+Qvg8...  BRASIL (BRA)
# 3      NaN  https://m.media-amazon.com/images/I/81flJeplFL...  BRASIL (BRA)
# 4      NaN  https://m.media-amazon.com/images/I/912CbMJHvA...  BRASIL (BRA)
# 5      NaN  https://m.media-amazon.com/images/I/615AxSP0+c...  BRASIL (BRA)
# 6      NaN  https://m.media-amazon.com/images/I/819Os22jca...  BRASIL (BRA)
# 7      NaN  https://m.media-amazon.com/images/I/81Lwj9haaf...  BRASIL (BRA)
# 8      NaN  https://m.media-amazon.com/images/I/A1wPC8Ppi5...  BRASIL (BRA)
# 9      NaN  https://m.media-amazon.com/images/I/61mRqaSLh+...  BRASIL (BRA)

# %%
# deleting duplicates
summary = summary.drop_duplicates().reset_index(drop=True)
# sending data to excel sheet
summary.to_excel('merge.xlsx', index=False)
summary.head(25)
# Out:
#          search      site            id  \
# 0   suplementos  amazonbr  caPWkuL._AC_
# 1   suplementos  amazonbr  bsTydWL._AC_
# 2   suplementos  amazonbr  onQvg8L._AC_
# 3   suplementos  amazonbr  orplFLL._AC_
# 4   suplementos  amazonbr  0GJHvAL._AC_
# 5   suplementos  amazonbr  0gP0+cL._AC_
# 6   suplementos  amazonbr  um2jcaL._AC_
# 7   suplementos  amazonbr  0ghaafL._AC_
# 8   suplementos  amazonbr  0GPpi5L._AC_
# 9   suplementos  amazonbr  a)SLh+S._AC_
# 10  suplementos  amazonbr  ab6ODrL._AC_
# 11  suplementos  amazonbr  e)RS5sL._AC_
# 12  suplementos  amazonbr  um5AQUL._AC_
# 13  suplementos  amazonbr  onIx2SS._AC_
# 14  suplementos  amazonbr  teR2k0L._AC_
# 15  suplementos  amazonbr  canUd4L._AC_
# 16  suplementos  amazonbr  asXg-aS._AC_
# 17  suplementos  amazonbr  catbgZL._AC_
# 18  suplementos  amazonbr  mlH-TzL._AC_
# 19  suplementos  amazonbr  ri0J1RL._AC_
# 20  suplementos  amazonbr  itENNJS._AC_
# 21  suplementos  amazonbr  to0gu+L._AC_
# 22  suplementos  amazonbr  um+2D9S._AC_
# 23  suplementos  amazonbr  orFQC5L._AC_
# 24  suplementos  amazonbr  asm1R1S._AC_
#
#                                                  name brand  price   oldprice  \
# 0      Nutriwhey Chocolate Pouch 907G, Integralmedica   NaN  50.63        NaN
# 1   Pré Hormonal Testodrol Gh - 60 Tabs Original -...   NaN   99.0        NaN
# 2   Best Whey (907G) - Sabor Brigadeiro Gourmet, A...   NaN  149.9        NaN
# 3                         Coq-10-60 Cápsulas, Vitafor   NaN  108.5        NaN
# 4                 Creatina 300G, Integralmedica, 300G   NaN  52.99        NaN
# 5   Suplemento Fortifit Pro Baunilha Danone Nutric...   NaN  116.0        NaN
# 6   Top Whey 3W (900G) - Sabor Mais Performance - ...   NaN   97.8  R$ 104,99
# 7   Nutren Protein, Suplemento Alimentar, Chocolat...   NaN  49.99   R$ 56,23
# 8        Creatine Pure Monohydrate, Black Skull, 150G   NaN   25.0        NaN
# 9   100% Whey Protein Refil 900g - Max Titanium (b...   NaN  70.31   R$ 93,00
# 10  Combo 2x Protein Fuse 900g Choc/Bau + 2x Bcaa ...   NaN    NaN        NaN
# 11  Kit Mass 3kg + Creatina 150g + BCAA 2400mg 100...   NaN  179.9        NaN
# 12       Multimax Complex - 90 Cápsulas, Max Titanium   NaN  36.14        NaN
# 13     Creatina 100% Pure (100g), Atlhetica Nutrition   NaN  34.69        NaN
# 14  Mass Titanium 17500 (3 Kg), Max Titanium, Choc...   NaN  89.11        NaN
# 15       Mega Pack Hardcore 30 Sachês, IntegralMedica   NaN  144.1        NaN
# 16  Memory Power (suplemento para memória) Vitgold...   NaN  61.42        NaN
# 17         Thermo Shake Diet 400g Morango, Probiótica   NaN    NaN        NaN
# 18  YoPRO Bebida Láctea UHT Chocolate 15g de prote...   NaN   6.39        NaN
# 19     Suplemento Mineral De Ferro 60 Caps, Apisnutri   NaN   29.9        NaN
# 20  Isolate Protein Mix Banana com Canela 900G, Pr...   NaN   50.5   R$ 71,94
# 21  Suplementação Nutricional - Guia prático para ...   NaN  153.0        NaN
# 22       2Hot - 200G Uva - Max Titanium, Max Titanium   NaN  56.94   R$ 70,40
# 23             Ômega 3 Epa Dha 1G (120 Caps), Vitafor   NaN   66.0        NaN
# 24  Maca Peruana Black (Preta) Maca, Color Andina ...   NaN   44.0   R$ 55,52
#
#    quantity                                              image       country
# 0       NaN  https://m.media-amazon.com/images/I/817zMBPWku...  BRASIL (BRA)
# 1       NaN  https://m.media-amazon.com/images/I/71KNWOTydW...  BRASIL (BRA)
# 2       NaN  https://m.media-amazon.com/images/I/912c8+Qvg8...  BRASIL (BRA)
# 3       NaN  https://m.media-amazon.com/images/I/81flJeplFL...  BRASIL (BRA)
# 4       NaN  https://m.media-amazon.com/images/I/912CbMJHvA...  BRASIL (BRA)
# 5       NaN  https://m.media-amazon.com/images/I/615AxSP0+c...  BRASIL (BRA)
# 6       NaN  https://m.media-amazon.com/images/I/819Os22jca...  BRASIL (BRA)
# 7       NaN  https://m.media-amazon.com/images/I/81Lwj9haaf...  BRASIL (BRA)
# 8       NaN  https://m.media-amazon.com/images/I/A1wPC8Ppi5...  BRASIL (BRA)
# 9       NaN  https://m.media-amazon.com/images/I/61mRqaSLh+...  BRASIL (BRA)
# 10      NaN  https://m.media-amazon.com/images/I/51oxTB6ODr...  BRASIL (BRA)
# 11      NaN  https://m.media-amazon.com/images/I/61EDR5RS5s...  BRASIL (BRA)
# 12      NaN  https://m.media-amazon.com/images/I/81DDBF5AQU...  BRASIL (BRA)
# 13      NaN  https://m.media-amazon.com/images/I/61WN8lIx2S...  BRASIL (BRA)
# 14      NaN  https://m.media-amazon.com/images/I/81MTuNR2k0...  BRASIL (BRA)
# 15      NaN  https://m.media-amazon.com/images/I/91XR6-nUd4...  BRASIL (BRA)
# 16      NaN  https://m.media-amazon.com/images/I/61WuNCXg-a...  BRASIL (BRA)
# 17      NaN  https://m.media-amazon.com/images/I/81cxLgtbgZ...  BRASIL (BRA)
# 18      NaN  https://m.media-amazon.com/images/I/51sx17H-Tz...  BRASIL (BRA)
# 19      NaN  https://m.media-amazon.com/images/I/514MS50J1R...  BRASIL (BRA)
# 20      NaN  https://m.media-amazon.com/images/I/81AvCLENNJ...  BRASIL (BRA)
# 21      NaN  https://m.media-amazon.com/images/I/41fbcp0gu+...  BRASIL (BRA)
# 22      NaN  https://m.media-amazon.com/images/I/71tZxw+2D9...  BRASIL (BRA)
# 23      NaN  https://m.media-amazon.com/images/I/715376FQC5...  BRASIL (BRA)
# 24      NaN  https://m.media-amazon.com/images/I/41uwDGm1R1...  BRASIL (BRA)

# %%
# visualize dataset individually
def show_dataframe(site):
    df = summary[summary['site']==site]
    print('datos: ', df.shape[0])
    print(df.info())
    return df
opts = list(summary.site.unique())
interact(show_dataframe, site=widgets.Dropdown(options=opts, value = 'amazonmx'))
# Out:
# interactive(children=(Dropdown(description='site', index=1, options=('amazonbr', 'amazonmx', 'americanas', 'be…
# <function __main__.show_dataframe(site)>

# %% [markdown]
# ### Summary table

# %%
pd.crosstab([summary.country, summary.site], summary.search, margins=True)
# Out:
# search                         suplementos  vitaminas    All
# country      site
# BRASIL (BRA) amazonbr                   66         62    128
#              americanas               9418       9940  19358
#              drogaraia                  96        120    216
#              drogariasaopaulo          480       1680   2160
#              lojadosuplemento           31         15     46
#              magalu                    186        296    482
#              magazine                   54          0     54
#              mercadolibrebr           2426        274   2700
#              mundoverde                  0         57     57
#              natue                     577         57    634
#              submarino                   0       3314   3314
# MEXICO (MEX) amazonmx                   70        125    195
#              benavides                  11         50     61
#              costco                    157        446    603
#              mercadolibremx           1932       2119   4051
#              sams                       23         15     38
#              sanborns                    0        279    279
#              sanpablofarmacia            0        354    354
#              supernaturista             29        604    633
#              walmart                   895        587   1482
# All                                  16451      20394  36845

# %%
summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36845 entries, 0 to 36844
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   search    36845 non-null  object
#  1   site      36845 non-null  object
#  2   id        35716 non-null  object
#  3   name      34906 non-null  object
#  4   brand     2115 non-null   object
#  5   price     35717 non-null  object
#  6   oldprice  12456 non-null  object
#  7   quantity  574 non-null    object
#  8   image     35719 non-null  object
#  9   country   36845 non-null  object
# dtypes: object(10)
# memory usage: 2.8+ MB

# %% [markdown]
# ### MASTER TABLE

# %%
master_table = pd.read_excel('master_table.xlsx', sheet_name="PM_LATAM_SPA (2)")
print(list(master_table.columns))
master_table
# Out:
# ['Pais', 'Corporación', 'Fabricante', 'Producto', 'Empaque', 'Classe Terapeutica Nivel 4 Concatenada', 'Tipo Producto']
#               Pais         Corporación          Fabricante          Producto  \
# 0     BRASIL (BRA)       3VS NUTRITION       3VS NUTRITION            VITA D
# 1     BRASIL (BRA)       3VS NUTRITION       3VS NUTRITION           MTI VIT
# 2     BRASIL (BRA)  A2F LAB FARMACEUTI  A2F LAB FARMACEUTI           LEV-TAM
# 3     BRASIL (BRA)  A2F LAB FARMACEUTI  A2F LAB FARMACEUTI           LEV-TAM
# 4     BRASIL (BRA)  A2F LAB FARMACEUTI  A2F LAB FARMACEUTI           IMUFORT
# ...            ...                 ...                 ...               ...
# 4602  MEXICO (MEX)               VITAE               VITAE           ROCAVIT
# 4603  MEXICO (MEX)               VITAE               VITAE           ROCAVIT
# 4604  MEXICO (MEX)               VITAE               VITAE           RETIGEL
# 4605  MEXICO (MEX)               VITAE               VITAE  ROCAVIT PLATINUM
# 4606  MEXICO (MEX)             ZERBONI             ZERBONI     CALCIO GI ZER
#
#                                     Empaque  \
# 0               VITA D CAPSULAS 2000IU x 75
# 1                     MTI VIT CPR A-Z x 120
# 2                 LEV-TAM CAPS MULT AZ x 60
# 3                 LEV-TAM CAPS SEN 50+ x 60
# 4                   IMUFORT CAPS 550MG x 30
# ...                                     ...
# 4602                      ROCAVIT CAPS x 30
# 4603                    ROCAVIT PERLAS x 30
# 4604                 RETIGEL CAPS 50 K x 40
# 4605             ROCAVIT PLATINUM CAPS x 30
# 4606  CALCIO GI ZER TABL  EFERV 500 MG x 12
#
#      Classe Terapeutica Nivel 4 Concatenada Tipo Producto
# 0                   A11C2 - VITAMIN D PLAIN         BRAND
# 1                 A11A4 - MVIT + MIN OTHERS         BRAND
# 2                 A11A4 - MVIT + MIN OTHERS         BRAND
# 3                 A11A4 - MVIT + MIN OTHERS         BRAND
# 4                A11X9 - ALL OTHER VITAMINS         BRAND
# ...                                     ...           ...
# 4602              A11A4 - MVIT + MIN OTHERS         BRAND
# 4603              A11A4 - MVIT + MIN OTHERS         BRAND
# 4604                A11C1 - VITAMIN A PLAIN         BRAND
# 4605              A11A4 - MVIT + MIN OTHERS         BRAND
# 4606                        A12A0 - CALCIUM       GENERIC
#
# [4607 rows x 7 columns]

# %%
# become string to lower to normalize when compare
master_table['Corporación'] = master_table['Corporación'].map(lambda x: x.lower())
master_table['Producto'] = master_table['Producto'].map(lambda x: x.lower())
master_table.head(10)
# Out:
#            Pais         Corporación          Fabricante      Producto  \
# 0  BRASIL (BRA)       3vs nutrition       3VS NUTRITION        vita d
# 1  BRASIL (BRA)       3vs nutrition       3VS NUTRITION       mti vit
# 2  BRASIL (BRA)  a2f lab farmaceuti  A2F LAB FARMACEUTI       lev-tam
# 3  BRASIL (BRA)  a2f lab farmaceuti  A2F LAB FARMACEUTI       lev-tam
# 4  BRASIL (BRA)  a2f lab farmaceuti  A2F LAB FARMACEUTI       imufort
# 5  BRASIL (BRA)  a2f lab farmaceuti  A2F LAB FARMACEUTI  suplementare
# 6  BRASIL (BRA)  a2f lab farmaceuti  A2F LAB FARMACEUTI  suplementare
# 7  BRASIL (BRA)  a2f lab farmaceuti  A2F LAB FARMACEUTI  suplementare
# 8  BRASIL (BRA)  a2f lab farmaceuti  A2F LAB FARMACEUTI  suplementare
# 9  BRASIL (BRA)  a2f lab farmaceuti  A2F LAB FARMACEUTI  suplementare
#
#                                      Empaque  \
# 0                VITA D CAPSULAS 2000IU x 75
# 1                      MTI VIT CPR A-Z x 120
# 2                  LEV-TAM CAPS MULT AZ x 60
# 3                  LEV-TAM CAPS SEN 50+ x 60
# 4                    IMUFORT CAPS 550MG x 30
# 5       SUPLEMENTARE CAPS MULT AZ 500MG x 60
# 6         SUPLEMENTARE CAPS HOMEM 500MG x 60
# 7        SUPLEMENTARE CAPS MULHER 550MG x 60
# 8        SUPLEMENTARE CAPS SENIOR 500MG x 60
# 9  SUPLEMENTARE CAPS CAL+V D 200IU x 60 /500
#
#   Classe Terapeutica Nivel 4 Concatenada Tipo Producto
# 0                A11C2 - VITAMIN D PLAIN         BRAND
# 1              A11A4 - MVIT + MIN OTHERS         BRAND
# 2              A11A4 - MVIT + MIN OTHERS         BRAND
# 3              A11A4 - MVIT + MIN OTHERS         BRAND
# 4             A11X9 - ALL OTHER VITAMINS         BRAND
# 5              A11A4 - MVIT + MIN OTHERS         BRAND
# 6              A11A4 - MVIT + MIN OTHERS         BRAND
# 7              A11A4 - MVIT + MIN OTHERS         BRAND
# 8              A11A4 - MVIT + MIN OTHERS         BRAND
# 9                        A12A0 - CALCIUM         BRAND

# %%
summary['name'] = summary['name'].astype(str)
summary['name'] = summary['name'].map(lambda x: x.lower())
summary
# Out:
#             search      site            id  \
# 0      suplementos  amazonbr  caPWkuL._AC_
# 1      suplementos  amazonbr  bsTydWL._AC_
# 2      suplementos  amazonbr  onQvg8L._AC_
# 3      suplementos  amazonbr  orplFLL._AC_
# 4      suplementos  amazonbr  0GJHvAL._AC_
# ...            ...       ...           ...
# 36840    vitaminas   walmart           NaN
# 36841    vitaminas   walmart           NaN
# 36842    vitaminas   walmart           NaN
# 36843    vitaminas   walmart           NaN
# 36844    vitaminas   walmart           NaN
#
#                                                     name                brand  \
# 0         nutriwhey chocolate pouch 907g, integralmedica                  NaN
# 1      pré hormonal testodrol gh - 60 tabs original -...                  NaN
# 2      best whey (907g) - sabor brigadeiro gourmet, a...                  NaN
# 3                            coq-10-60 cápsulas, vitafor                  NaN
# 4                    creatina 300g, integralmedica, 300g                  NaN
# ...                                                  ...                  ...
# 36840   equinácea extracto fluido 30 ml green house (...          green house
# 36841   mynus oxomio extracto de frijol blanco 60 cáp...               oxomio
# 36842   biotina 500 mg 30 cápsulas pro tgt cosmetics....    pro tgt cosmetics
# 36843                   gomitas flor de jaguar dfn 180 g       flor de jaguar
# 36844   multivitaminico universal nutrition animal pa...  universal nutrition
#
#            price oldprice quantity  \
# 0          50.63      NaN      NaN
# 1           99.0      NaN      NaN
# 2          149.9      NaN      NaN
# 3          108.5      NaN      NaN
# 4          52.99      NaN      NaN
# ...          ...      ...      ...
# 36840    $135.00      NaN      NaN
# 36841    $750.00      NaN      NaN
# 36842    $240.00      NaN      NaN
# 36843    $325.00      NaN      NaN
# 36844  $1,066.62      NaN      NaN
#
#                                                    image       country
# 0      https://m.media-amazon.com/images/I/817zMBPWku...  BRASIL (BRA)
# 1      https://m.media-amazon.com/images/I/71KNWOTydW...  BRASIL (BRA)
# 2      https://m.media-amazon.com/images/I/912c8+Qvg8...  BRASIL (BRA)
# 3      https://m.media-amazon.com/images/I/81flJeplFL...  BRASIL (BRA)
# 4      https://m.media-amazon.com/images/I/912CbMJHvA...  BRASIL (BRA)
# ...                                                  ...           ...
# 36840                                                NaN  MEXICO (MEX)
# 36841                                                NaN  MEXICO (MEX)
# 36842                                                NaN  MEXICO (MEX)
# 36843                                                NaN  MEXICO (MEX)
# 36844                                                NaN  MEXICO (MEX)
#
# [36845 rows x 10 columns]

# %%
reference_brands = master_table['Corporación'].unique().tolist()
reference_products = master_table['Producto'].unique().tolist()
print(summary.shape[0])

# initializing columns
summary.loc[n, 'brand_match'] = np.nan
summary.loc[n, 'product_match'] = np.nan

print(summary.columns)
for n in range(summary.shape[0]):

    matches_brand = []
    matches_product = []
    try:
        for official_brand in reference_brands:
            if official_brand in str(summary.loc[n, 'name']):
                matches_brand.append(official_brand)

        for official_product in reference_products:
            if official_product in str(summary.loc[n, 'name']):
                matches_product.append(official_product)
    except Exception as e:
        print(e)
    
    if matches_brand:
        summary.loc[n, 'brand_match'] = ', '.join(matches_brand)
    else:
        summary.loc[n, 'brand_match'] = np.nan

    if matches_product:
        summary.loc[n, 'product_match'] = ', '.join(matches_product)
    else:
        summary.loc[n, 'product_match'] = np.nan

# summary
# Out:
# 36845
# Index(['search', 'site', 'id', 'name', 'brand', 'price', 'oldprice',
#        'quantity', 'image', 'country', 'brand_match', 'product_match'],
#       dtype='object')
# 36845

# %%
test = summary.copy()

# %%
df_1 = test[test['product_match'].notna()]
df_1[['name', 'brand', 'brand_match', 'product_match']].head(25)
# Out:
#                                                  name brand  \
# 1   pré hormonal testodrol gh - 60 tabs original -...   NaN
# 12       multimax complex - 90 cápsulas, max titanium   NaN
# 30  creatina monohidratada pura - 300g - probiótic...   NaN
# 44           omega 3 1000mg 200 cápsulas, vitaminlife   NaN
# 45       apisnutri levedo de cerveja, 400 comprimidos   NaN
# 66  diarium multivitamínico, vitaminlife, 120 cáps...   NaN
# 67        vitamina e 400ui - 60 softgels, vitaminlife   NaN
# 69                 sérum facial vitamina c 10, tracta   NaN
# 71  vitamina ultra d3 2.000 ui 100 vitgold 100 cáp...   NaN
# 72         revigoran vitamina c 60 cápsulas, nutrends   NaN
# 73                                         vitamina d   NaN
# 74                       vita d3-60 cápsulas, vitafor   NaN
# 75  vit d 2000ui - 60 softgels - vitaminlife, xtr ...   NaN
# 76  cálcio + magnésio + zinco + vitamina d3 + vita...   NaN
# 79                revigoran a-z 60 cápsulas, nutrends   NaN
# 82     vitamina d-3 2.000 ui now foods (120 cápsulas)   NaN
# 83                 vitamina e 400 ui vitgold 100 caps   NaN
# 84       multimax complex - 90 cápsulas, max titanium   NaN
# 85  complexo b, biotina, magnésio, potássio, zinco...   NaN
# 86              vitamina c 1.000 mg vitgold 100 compr   NaN
# 87          sweet grow vitaminas para cabelos e unhas   NaN
# 88            vita c3 120 cápsulas de 1000mg, vitafor   NaN
# 89  vitamina d3 colecalciferol 2000 ui - 60 caps l...   NaN
# 91                        biotina - 60 cáps - soulife   NaN
# 93  vitamina d 2000ui – sundown naturals 200 cápsulas   NaN
#
#                brand_match                               product_match
# 1                      NaN                            testodrol, testo
# 12            max titanium                            multimax complex
# 30                     NaN                                         ada
# 44             vitaminlife                                 vitaminlife
# 45               apisnutri                           levedo de cerveja
# 66             vitaminlife             multivita, diarium, vitaminlife
# 67             vitaminlife                     vitamina e, vitaminlife
# 69                     NaN                                  vitamina c
# 71          vitgold, ultra                                    ultra d3
# 72                     NaN              vitamina c, revigor, revigoran
# 73                     NaN                                  vitamina d
# 74                 vitafor                             vita d, vita d3
# 75  nutrition, vitaminlife                          vit d, vitaminlife
# 76                     NaN        vitamina d3, vitamina d, zinco, zinc
# 79                     NaN                     revigor, revigoran, a-z
# 82                     NaN                                  vitamina d
# 83                 vitgold                                  vitamina e
# 84            max titanium                            multimax complex
# 85                     NaN            complexo b, zinco, biotina, zinc
# 86                 vitgold                                  vitamina c
# 87                     NaN                                    grow vit
# 88                 vitafor                             vita c, vita c3
# 89                     NaN  vitamina d3, vitamina d, d3 colecalciferol
# 91                     NaN                                     biotina
# 93                     NaN                                  vitamina d

# %%
print('total of rows founded: ', df_1.shape[0])
print('quantities filled: ', df_1[df_1['quantity'].notna()].shape[0])
print('missing in quantity field: ',  df_1[df_1['quantity'].isnull()].shape[0])
# Out:
# total of rows founded:  17953
# quantities filled:  266
# missing in quantity field:  17687

# %%
# function to extract matches with quantities type
def extract_quantity(n):
    try:
#         query = r"(\d+[.,]?\d*)(?:[\s\d\-\+\/]*)(?:Cápsulas|Mg|cápsulas|capsulas|Cápsulas|mg|mL|tabs)"
        query = r"(\d+)\s(Cápsulas|Mg|cápsulas|capsulas|Cápsulas|mg|mL|tabs)\b"
        output = re.search(query, n).group()
        if output:
          return output
        else:
          return ''
    except:
        return ''

test_match_no_quantity = df_1[df_1['quantity'].isnull()]
test_match_no_quantity['quantity'] = test_match_no_quantity['name'].apply(lambda x: extract_quantity(x))
test_match_no_quantity
# Out:
# <ipython-input-43-1bd19d8880bd>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_match_no_quantity['quantity'] = test_match_no_quantity['name'].apply(lambda x: extract_quantity(x))
#             search      site            id  \
# 1      suplementos  amazonbr  bsTydWL._AC_
# 12     suplementos  amazonbr  um5AQUL._AC_
# 30     suplementos  amazonbr  ca4m+KL._AC_
# 44     suplementos  amazonbr  fe3+xkL._AC_
# 45     suplementos  amazonbr  osLe1aL._AC_
# ...            ...       ...           ...
# 36827    vitaminas   walmart           NaN
# 36837    vitaminas   walmart           NaN
# 36841    vitaminas   walmart           NaN
# 36842    vitaminas   walmart           NaN
# 36844    vitaminas   walmart           NaN
#
#                                                     name                brand  \
# 1      pré hormonal testodrol gh - 60 tabs original -...                  NaN
# 12          multimax complex - 90 cápsulas, max titanium                  NaN
# 30     creatina monohidratada pura - 300g - probiótic...                  NaN
# 44              omega 3 1000mg 200 cápsulas, vitaminlife                  NaN
# 45          apisnutri levedo de cerveja, 400 comprimidos                  NaN
# ...                                                  ...                  ...
# 36827   colágeno premium con biotina 180 cápsula sola...              solanum
# 36837   cla oxomio ácido linoléico conjugado 180 cáps...               oxomio
# 36841   mynus oxomio extracto de frijol blanco 60 cáp...               oxomio
# 36842   biotina 500 mg 30 cápsulas pro tgt cosmetics....    pro tgt cosmetics
# 36844   multivitaminico universal nutrition animal pa...  universal nutrition
#
#            price  oldprice      quantity  \
# 1           99.0       NaN       60 tabs
# 12         36.14       NaN   90 cápsulas
# 30          36.9  R$ 44,90
# 44         59.91       NaN  200 cápsulas
# 45         16.99  R$ 18,00
# ...          ...       ...           ...
# 36827    $549.00       NaN
# 36837  $1,100.00       NaN
# 36841    $750.00       NaN
# 36842    $240.00       NaN        500 mg
# 36844  $1,066.62       NaN
#
#                                                    image       country  \
# 1      https://m.media-amazon.com/images/I/71KNWOTydW...  BRASIL (BRA)
# 12     https://m.media-amazon.com/images/I/81DDBF5AQU...  BRASIL (BRA)
# 30     https://m.media-amazon.com/images/I/81g9r84m+K...  BRASIL (BRA)
# 44     https://m.media-amazon.com/images/I/71GxTD3+xk...  BRASIL (BRA)
# 45     https://m.media-amazon.com/images/I/61lLfNLe1a...  BRASIL (BRA)
# ...                                                  ...           ...
# 36827                                                NaN  MEXICO (MEX)
# 36837                                                NaN  MEXICO (MEX)
# 36841                                                NaN  MEXICO (MEX)
# 36842                                                NaN  MEXICO (MEX)
# 36844                                                NaN  MEXICO (MEX)
#
#         brand_match      product_match
# 1               NaN   testodrol, testo
# 12     max titanium   multimax complex
# 30              NaN                ada
# 44      vitaminlife        vitaminlife
# 45        apisnutri  levedo de cerveja
# ...             ...                ...
# 36827           NaN            biotina
# 36837           NaN                mio
# 36841           NaN                mio
# 36842           NaN            biotina
# 36844     nutrition          multivita
#
# [17687 rows x 12 columns]

# %%
test_match_no_quantity.head(25)
# Out:
#          search      site            id  \
# 1   suplementos  amazonbr  bsTydWL._AC_
# 12  suplementos  amazonbr  um5AQUL._AC_
# 30  suplementos  amazonbr  ca4m+KL._AC_
# 44  suplementos  amazonbr  fe3+xkL._AC_
# 45  suplementos  amazonbr  osLe1aL._AC_
# 66    vitaminas  amazonbr  asRSoZL._AC_
# 67    vitaminas  amazonbr  fetBXML._AC_
# 69    vitaminas  amazonbr  taTTODL._AC_
# 71    vitaminas  amazonbr  asBU6yL._AC_
# 72    vitaminas  amazonbr  dsxMgsL._AC_
# 73    vitaminas  amazonbr   DBZrkL._AC_
# 74    vitaminas  amazonbr  orOAjJL._AC_
# 75    vitaminas  amazonbr  onIWm8L._AC_
# 76    vitaminas  amazonbr  inw13oL._AC_
# 79    vitaminas  amazonbr  dsVN5sL._AC_
# 82    vitaminas  amazonbr  s)tyeiL._AC_
# 83    vitaminas  amazonbr  psjd+CL._AC_
# 84    vitaminas  amazonbr  um5AQUL._AC_
# 85    vitaminas  amazonbr  s.gC8mS._AC_
# 86    vitaminas  amazonbr  prprkgL._AC_
# 87    vitaminas  amazonbr  asIBmgL._AC_
# 88    vitaminas  amazonbr  orbsF3S._AC_
# 89    vitaminas  amazonbr  onr+-QL._AC_
# 91    vitaminas  amazonbr  feD3ykL._AC_
# 93    vitaminas  amazonbr  asph0wL._AC_
#
#                                                  name brand   price  oldprice  \
# 1   pré hormonal testodrol gh - 60 tabs original -...   NaN    99.0       NaN
# 12       multimax complex - 90 cápsulas, max titanium   NaN   36.14       NaN
# 30  creatina monohidratada pura - 300g - probiótic...   NaN    36.9  R$ 44,90
# 44           omega 3 1000mg 200 cápsulas, vitaminlife   NaN   59.91       NaN
# 45       apisnutri levedo de cerveja, 400 comprimidos   NaN   16.99  R$ 18,00
# 66  diarium multivitamínico, vitaminlife, 120 cáps...   NaN   34.77       NaN
# 67        vitamina e 400ui - 60 softgels, vitaminlife   NaN    39.9  R$ 42,56
# 69                 sérum facial vitamina c 10, tracta   NaN    43.9       NaN
# 71  vitamina ultra d3 2.000 ui 100 vitgold 100 cáp...   NaN   77.59       NaN
# 72         revigoran vitamina c 60 cápsulas, nutrends   NaN    33.9       NaN
# 73                                         vitamina d   NaN    38.9  R$ 54,40
# 74                       vita d3-60 cápsulas, vitafor   NaN   51.83       NaN
# 75  vit d 2000ui - 60 softgels - vitaminlife, xtr ...   NaN   39.54       NaN
# 76  cálcio + magnésio + zinco + vitamina d3 + vita...   NaN    56.0       NaN
# 79                revigoran a-z 60 cápsulas, nutrends   NaN   27.52  R$ 30,90
# 82     vitamina d-3 2.000 ui now foods (120 cápsulas)   NaN    75.0       NaN
# 83                 vitamina e 400 ui vitgold 100 caps   NaN  108.76       NaN
# 84       multimax complex - 90 cápsulas, max titanium   NaN   36.14       NaN
# 85  complexo b, biotina, magnésio, potássio, zinco...   NaN    34.9       NaN
# 86              vitamina c 1.000 mg vitgold 100 compr   NaN  118.29       NaN
# 87          sweet grow vitaminas para cabelos e unhas   NaN    44.0       NaN
# 88            vita c3 120 cápsulas de 1000mg, vitafor   NaN   74.18  R$ 79,00
# 89  vitamina d3 colecalciferol 2000 ui - 60 caps l...   NaN    36.9       NaN
# 91                        biotina - 60 cáps - soulife   NaN    26.9       NaN
# 93  vitamina d 2000ui – sundown naturals 200 cápsulas   NaN   139.9       NaN
#
#         quantity                                              image  \
# 1        60 tabs  https://m.media-amazon.com/images/I/71KNWOTydW...
# 12   90 cápsulas  https://m.media-amazon.com/images/I/81DDBF5AQU...
# 30                https://m.media-amazon.com/images/I/81g9r84m+K...
# 44  200 cápsulas  https://m.media-amazon.com/images/I/71GxTD3+xk...
# 45                https://m.media-amazon.com/images/I/61lLfNLe1a...
# 66  120 cápsulas  https://m.media-amazon.com/images/I/81qLUhRSoZ...
# 67                https://m.media-amazon.com/images/I/81Ky35tBXM...
# 69                https://m.media-amazon.com/images/I/61Qp-gTTOD...
# 71  100 cápsulas  https://m.media-amazon.com/images/I/61ld4gBU6y...
# 72   60 cápsulas  https://m.media-amazon.com/images/I/611iy4xMgs...
# 73                https://m.media-amazon.com/images/I/917jQtBZrk...
# 74   60 cápsulas  https://m.media-amazon.com/images/I/71tIBGOAjJ...
# 75                https://m.media-amazon.com/images/I/81FeLUIWm8...
# 76                https://m.media-amazon.com/images/I/615emtw13o...
# 79   60 cápsulas  https://m.media-amazon.com/images/I/61MP6cVN5s...
# 82  120 cápsulas  https://m.media-amazon.com/images/I/71xtoptyei...
# 83                https://m.media-amazon.com/images/I/51V-IEjd+C...
# 84   90 cápsulas  https://m.media-amazon.com/images/I/81DDBF5AQU...
# 85   60 cápsulas  https://m.media-amazon.com/images/I/61bFuRgC8m...
# 86        000 mg  https://m.media-amazon.com/images/I/51DHACprkg...
# 87                https://m.media-amazon.com/images/I/61k-sZIBmg...
# 88  120 cápsulas  https://m.media-amazon.com/images/I/419lP1bsF3...
# 89                https://m.media-amazon.com/images/I/71Sy5wr+-Q...
# 91                https://m.media-amazon.com/images/I/51VfXqD3yk...
# 93  200 cápsulas  https://m.media-amazon.com/images/I/51bF43ph0w...
#
#          country             brand_match  \
# 1   BRASIL (BRA)                     NaN
# 12  BRASIL (BRA)            max titanium
# 30  BRASIL (BRA)                     NaN
# 44  BRASIL (BRA)             vitaminlife
# 45  BRASIL (BRA)               apisnutri
# 66  BRASIL (BRA)             vitaminlife
# 67  BRASIL (BRA)             vitaminlife
# 69  BRASIL (BRA)                     NaN
# 71  BRASIL (BRA)          vitgold, ultra
# 72  BRASIL (BRA)                     NaN
# 73  BRASIL (BRA)                     NaN
# 74  BRASIL (BRA)                 vitafor
# 75  BRASIL (BRA)  nutrition, vitaminlife
# 76  BRASIL (BRA)                     NaN
# 79  BRASIL (BRA)                     NaN
# 82  BRASIL (BRA)                     NaN
# 83  BRASIL (BRA)                 vitgold
# 84  BRASIL (BRA)            max titanium
# 85  BRASIL (BRA)                     NaN
# 86  BRASIL (BRA)                 vitgold
# 87  BRASIL (BRA)                     NaN
# 88  BRASIL (BRA)                 vitafor
# 89  BRASIL (BRA)                     NaN
# 91  BRASIL (BRA)                     NaN
# 93  BRASIL (BRA)                     NaN
#
#                                  product_match
# 1                             testodrol, testo
# 12                            multimax complex
# 30                                         ada
# 44                                 vitaminlife
# 45                           levedo de cerveja
# 66             multivita, diarium, vitaminlife
# 67                     vitamina e, vitaminlife
# 69                                  vitamina c
# 71                                    ultra d3
# 72              vitamina c, revigor, revigoran
# 73                                  vitamina d
# 74                             vita d, vita d3
# 75                          vit d, vitaminlife
# 76        vitamina d3, vitamina d, zinco, zinc
# 79                     revigor, revigoran, a-z
# 82                                  vitamina d
# 83                                  vitamina e
# 84                            multimax complex
# 85            complexo b, zinco, biotina, zinc
# 86                                  vitamina c
# 87                                    grow vit
# 88                             vita c, vita c3
# 89  vitamina d3, vitamina d, d3 colecalciferol
# 91                                     biotina
# 93                                  vitamina d

# %%
# query = r"(\d+)\s(Cápsulas|Mg|ml|cápsulas|mL|tabs)\b"
# output = ' '.join(re.match(query, 'pré hormonal testodrol gh - 60 tabs original').groups())
# output


# re.search(r"(\d+)\s(Cápsulas|Mg|ml|cápsulas|mL|tabs)\b", 'pré hormonal testodrol gh - 60 tabs original').group()

# %%
# print(re.match(query, 'pré hormonal testodrol gh - 60 tabs original'))

# %%
# test.dropna(subset=["product_match"], how="any", axis=0, inplace=True)
# test

# %%
# def extract_quantity(n):
#     try:
#         y = re.findall(r"(\d+[.,]?\d*)(?:[\s\d\-\+\/]*)(?:Cápsulas|Mg|cápsulas|capsulas|Cápsulas|mg|mL)", n)
#         x = y[0]
#         if x:
#           return x
#         else:
#           return ''
#     except:
#         return ''

# %%
# def extract_brand(n):
#     try:
#         y = re.findall(r"\s-\s.*", n)
#         x = y[0].replace(' -', '')
#         if x:
#           return x
#         else:
#           return ''
#     except:
#         return ''

# summary['quantity'] = summary['name'].apply(lambda x: extract_quantity(x))
# summary['brand'] = summary['name'].apply(lambda x: extract_brand(x))

# summary.head(15)

# %%
# df.info()

# %%
# print(df.name[12])

# %%
# df['quantity'] = df.name.apply(lambda n: re.findall(r"[0-9]{2,4}", n)[0]) + ' ' + df.name.apply(lambda n: re.findall(r"[0-9]{2,4}\s(\w*)", n)[0]

# %%
# summary = pd.concat(list_dataframes, ignore_index=True)
# print(summary.shape)
# summary = summary.dropna(how='all', axis=0).drop_duplicates(keep=False).reset_index(drop=True)
# summary.quantity[20:]

# %%
# summary.info()

# %%
# summary.name.iloc[1].lower()

# %%
# summary.to_excel('summaryv1.xlsx', index=False)

# %%
# string = 'Kit Lavitan Mais Mulher 360 Cápsulas barato Igual Centrum oferta - Sampafarmstore'
# xx = re.findall(r"[0-9]{2,4}", string)[0]
# print(xx)
# xx = re.findall(r"[0-9]{2,4}\s(\w*)", string)[0]
# xx

# %%
# total['newid'] = total.name.str[-2:] + total.image.str[-20:-10]
# total

# %%
# total['newid'] = total['name'].str(-2:)

# %%
# 'quantity' not in ['a', 'b', 'quantity']

# %%
# summary.name

# %%
# '|'.join(["hours", "hour", "hrs", "days", "day", "minutes", "minute", "min"])

# %%
# xx = [1]
# if xx:
#     print('aaaa')
